# %%
from feature_extraction import get_feature
from cnn import run_pipeline
# Out:
# Backend: GPU (CuPy)

# %%
mel = get_feature("mel")

# %%
train_x, train_y, train_s = mel["train"]
val_x,   val_y,   val_s   = mel["val"]
test_x,  test_y,  test_s  = mel["test"]

# %%
run_pipeline(
    train_x, train_y,
    val_x,   val_y,
    test_x,  test_y,
    labels     = ["Human", "AI"],
    scenario   = "mel",
    train_s    = train_s,
    val_s      = val_s,
    test_s     = test_s,
)
# Out:
# Using device: GPU (CuPy)
# train_x shape: (15038, 1, 128, 157)
# Number of classes: 2
# CNNModel(
#   (features)
#     Conv2d
#     BatchNorm2d
#     ReLU
#     MaxPool2d
#     Dropout
#     Conv2d
#     BatchNorm2d
#     ReLU
#     MaxPool2d
#     Dropout
#     Conv2d
#     BatchNorm2d
#     ReLU
#     MaxPool2d
#     Dropout
#     Conv2d
#     BatchNorm2d
#     ReLU
#     AdaptiveAvgPool2d
#     Dropout
#   (classifier)
#     Flatten
#     Linear
#     ReLU
#     Dropout
#     Linear
#     ReLU
#     Dropout
#     Linear
# )
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_pipeline(
#       2     train_x, train_y,
#       3     val_x,   val_y,
#       4     test_x,  test_y,
#
# File c:\Users\bayub\Documents\ai-music-classification\cnn.py:687, in run_pipeline(train_x, train_y, val_x, val_y, test_x, test_y, labels, epochs, patience, batch_size, scenario, train_s, val_s, test_s)
#     681 (train_loader, val_loader, test_loader), num_classes = data_preparation(
#     682     train_x, train_y, val_x, val_y, test_x, test_y, batch_size,
#     683     train_s=train_s, val_s=val_s, test_s=test_s)
#     685 model, criterion, optimizer, scheduler = build_training_components(num_classes)
# --> 687 history = train(
#     688     model, train_loader, val_loader, criterion, optimizer, scheduler,
#     689     epochs=epochs, patience=patience, save_path=f"best_{scenario}_model")
#     691 preds, targets = evaluate(
#     692     model, test_loader, criterion, save_path=f"best_{scenario}_model")
#     694 plot_history(history,          save_path=f"{scenario}_training_history.png")
#
# File c:\Users\bayub\Documents\ai-music-classification\cnn.py:542, in train(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs, patience, save_path)
#     539 best_val_loss, counter = float("inf"), 0
#     541 for epoch in range(epochs):
# --> 542     tr_loss, tr_acc = run_epoch(model, train_loader, criterion, optimizer)
#     543     va_loss, va_acc = run_epoch(model, val_loader,   criterion)
#     545     scheduler.step(va_loss)
#
# File c:\Users\bayub\Documents\ai-music-classification\cnn.py:507, in run_epoch(model, loader, criterion, optimizer)
#     504 for inputs, targets, _ in loader:         # _ = source strings, unused here
#     505     if is_train: optimizer.zero_grad()
# --> 507     logits = model.forward(inputs)
#     508     loss   = criterion(logits, targets)
#     510     if is_train:
#
# File c:\Users\bayub\Documents\ai-music-classification\cnn.py:315, in CNNModel.forward(self, x)
#     314 def forward(self, x):
# --> 315     return self.classifier.forward(self.features.forward(x))
#
# File c:\Users\bayub\Documents\ai-music-classification\cnn.py:273, in Sequential.forward(self, x)
#     272 def forward(self, x):
# --> 273     for l in self.layers: x = l.forward(x)
#     274     return x
#
# File c:\Users\bayub\Documents\ai-music-classification\cnn.py:104, in Conv2d.forward(self, x)
#     102 N = x.shape[0]
#     103 # col @ W.T : (N,oH*oW,C_out)  →  transpose  →  reshape
# --> 104 out = (col @ self.params['W'].T + self.params['b']) \
#     105         .transpose(0, 2, 1).reshape(N, self.out_ch, oH, oW)
#     106 self.cache = (x, col)
#     107 return out
#
# File cupy/_core/core.pyx:1513, in cupy._core.core._ndarray_base.__matmul__()
# -> 1513 'Could not get source, probably due dynamically evaluated source code.'
#
# File cupy/_core/_routines_linalg.pyx:842, in cupy._core._routines_linalg.matmul()
# --> 842 'Could not get source, probably due dynamically evaluated source code.'
#
# File c:\Users\bayub\anaconda3\envs\music-classification\Lib\site-packages\cupy_backends\cuda\libs\__init__.py:41, in __getattr__(name)
#      38             raise ImportError(str(e)) from e
#      40 if name in (_submodules + _submodules_runtime_link):
# ---> 41     return _importlib.import_module(f'cupy_backends.cuda.libs.{name}')
#      43 raise AttributeError(
#      44     f"module {__name__!r} has no attribute {name!r}")
#
# File c:\Users\bayub\anaconda3\envs\music-classification\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# ImportError: DLL load failed while importing cublas: The specified module could not be found.
