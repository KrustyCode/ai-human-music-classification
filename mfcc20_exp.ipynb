# %%
from feature_extraction import get_feature
from cnn import run_pipeline
# Out:
# Backend: GPU (CuPy)

# %%
mfcc_20 = get_feature("mfcc_20")

# %%
train_x, train_y, train_s = mfcc_20["train"]
val_x,   val_y,   val_s   = mfcc_20["val"]
test_x,  test_y,  test_s  = mfcc_20["test"]

# %%
run_pipeline(
    train_x, train_y,
    val_x,   val_y,
    test_x,  test_y,
    labels     = ["Human", "AI"],
    scenario   = "mfcc_20",
    train_s    = train_s,
    val_s      = val_s,
    test_s     = test_s,
)
# Out:
# Using device: GPU (CuPy)
# train_x shape: (15038, 1, 20, 157)
# Number of classes: 2
# CNNModel(
#   (features)
#     Conv2d
#     BatchNorm2d
#     ReLU
#     MaxPool2d
#     Dropout
#     Conv2d
#     BatchNorm2d
#     ReLU
#     MaxPool2d
#     Dropout
#     Conv2d
#     BatchNorm2d
#     ReLU
#     MaxPool2d
#     Dropout
#     Conv2d
#     BatchNorm2d
#     ReLU
#     AdaptiveAvgPool2d
#     Dropout
#   (classifier)
#     Flatten
#     Linear
#     ReLU
#     Dropout
#     Linear
#     ReLU
#     Dropout
#     Linear
# )
#
# Epoch [1/50]
#   Train — Loss: 0.6661  Acc: 0.6593
#   Val   — Loss: 0.6279  Acc: 0.6363
#   ✓ Best model saved → best_mfcc_20_model.npz
#
# Epoch [2/50]
#   Train — Loss: 0.5565  Acc: 0.7429
#   Val   — Loss: 0.6378  Acc: 0.6201
#
# Epoch [3/50]
#   Train — Loss: 0.5246  Acc: 0.7701
#   Val   — Loss: 0.5705  Acc: 0.7241
#   ✓ Best model saved → best_mfcc_20_model.npz
#
# Epoch [4/50]
#   Train — Loss: 0.5042  Acc: 0.7888
# ...
