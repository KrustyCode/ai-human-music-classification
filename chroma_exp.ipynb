# %%
from feature_extraction import get_feature
from cnn import run_pipeline

# %%
chroma = get_feature("chroma")

# %%
train_x, train_y, train_s = chroma["train"]
val_x,   val_y,   val_s   = chroma["val"]
test_x,  test_y,  test_s  = chroma["test"]

# %%
run_pipeline(
    train_x, train_y,
    val_x,   val_y,
    test_x,  test_y,
    labels     = ["Human", "AI"],
    scenario   = "chroma",
    train_s    = train_s,
    val_s      = val_s,
    test_s     = test_s,
)
