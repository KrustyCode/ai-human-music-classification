# %%
from feature_extraction import get_feature
from cnn import run_pipeline
# Out:
# Backend: GPU (CuPy)

# %%
mel = get_feature("mel")

# %%
train_x, train_y, train_s = mel["train"]
val_x,   val_y,   val_s   = mel["val"]
test_x,  test_y,  test_s  = mel["test"]

# %%
run_pipeline(
    train_x, train_y,
    val_x,   val_y,
    test_x,  test_y,
    labels     = ["Human", "AI"],
    scenario   = "mel",
    train_s    = train_s,
    val_s      = val_s,
    test_s     = test_s,
)
# Out:
# Using device: GPU (CuPy)
# train_x shape: (15038, 1, 128, 157)
# Number of classes: 2
# CNNModel(
#   (features)
#     Conv2d
#     BatchNorm2d
#     ReLU
#     MaxPool2d
#     Dropout
#     Conv2d
#     BatchNorm2d
#     ReLU
#     MaxPool2d
#     Dropout
#     Conv2d
#     BatchNorm2d
#     ReLU
#     MaxPool2d
#     Dropout
#     Conv2d
#     BatchNorm2d
#     ReLU
#     AdaptiveAvgPool2d
#     Dropout
#   (classifier)
#     Flatten
#     Linear
#     ReLU
#     Dropout
#     Linear
#     ReLU
#     Dropout
#     Linear
# )
#
# Epoch [1/50]
#   Train — Loss: 0.6094  Acc: 0.7174
#   Val   — Loss: 0.4852  Acc: 0.8253
#   ✓ Best model saved → best_mel_model.npz
#
# Epoch [2/50]
#   Train — Loss: 0.4565  Acc: 0.8345
#   Val   — Loss: 0.4240  Acc: 0.8718
#   ✓ Best model saved → best_mel_model.npz
#
# Epoch [3/50]
#   Train — Loss: 0.3773  Acc: 0.8916
#   Val   — Loss: 0.3936  Acc: 0.8808
#   ✓ Best model saved → best_mel_model.npz
#
# Epoch [4/50]
# ...
